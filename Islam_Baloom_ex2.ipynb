# %% [markdown]
# GitHub: https://github.com/mostafa11sbetan/ex2

# %% [markdown]
# GitHub: https://github.com/islam-web-code/ex2

# %% [markdown]
# Libraries (don't change)

# %%
# !pip -q install torchinfo

from dataclasses import dataclass
from typing import List, Callable, Optional, Tuple

import numpy as np
import time
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
from torchinfo import summary

from sklearn.metrics import confusion_matrix, classification_report

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Device (don't change)

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
use_amp = (DEVICE == "cuda")

print(f"Using device: {DEVICE}")
print(f"Mixed precision (AMP): {use_amp}")
# Out:
# Using device: cpu
# Mixed precision (AMP): False

# %% [markdown]
# Data (don't change)

# %%
class DataManager:
    def __init__(self, dataset_class, root: str = "./data", val_fraction: float = 0.1,
                 batch_size: int = 32, seed: int = 42):
        self.dataset_class = dataset_class
        self.root = root
        self.val_fraction = val_fraction
        self.batch_size = batch_size
        self.seed = seed

        self.transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.1918,), (0.3483,))
        ])

    def get_loaders(self) -> Tuple[DataLoader, DataLoader, DataLoader]:
        full_train = self.dataset_class(root=self.root, train=True,
                                        download=True, transform=self.transform)
        test_ds = self.dataset_class(root=self.root, train=False,
                                     download=True, transform=self.transform)

        val_size = int(len(full_train) * self.val_fraction)
        train_size = len(full_train) - val_size

        generator = torch.Generator().manual_seed(self.seed)
        train_ds, val_ds = random_split(full_train, [train_size, val_size], generator=generator)

        train_loader = DataLoader(train_ds, batch_size=self.batch_size,
                                  shuffle=True, num_workers=2, pin_memory=True)
        val_loader   = DataLoader(val_ds,   batch_size=self.batch_size,
                                  shuffle=False, num_workers=2, pin_memory=True)
        test_loader  = DataLoader(test_ds,  batch_size=self.batch_size,
                                  shuffle=False, num_workers=2, pin_memory=True)

        print(f"Train: {len(train_ds)} | Val: {len(val_ds)} | Test: {len(test_ds)}")
        return train_loader, val_loader, test_loader

# %% [markdown]
# Configurations (don't change)

# %%
@dataclass
class LayerSpec:
    out_dim: int
    activation: Callable[[torch.Tensor], torch.Tensor] = F.relu
    dropout: float = 0.0
    batch_norm: bool = True
    weight_decay: float = 0.0

@dataclass
class ModelConfig:
    input_dim: Tuple[int, int, int] = (1, 28, 28)
    num_classes: int = 10
    layers: List[LayerSpec] = None

@dataclass
class TrainConfig:
    batch_size: int = 64
    epochs: int = 100
    lr: float = 1e-4
    patience: int = 15
    min_delta: float = 1e-4
    val_fraction: float = 0.1
    seed: int = 42

# %% [markdown]
# Model

# %%
class MLPFromConfig(nn.Module):
    def __init__(self, config: ModelConfig):
        super().__init__()
        flat_dim = config.input_dim[0] * config.input_dim[1] * config.input_dim[2]
        self.layers_specs = config.layers
        layers = []
        prev_dim = flat_dim

        for i, spec in enumerate(config.layers):
            linear = nn.Linear(prev_dim, spec.out_dim)

            layers.append(linear)
            if spec.batch_norm:
                layers.append(nn.BatchNorm1d(spec.out_dim))
            if spec.dropout > 0:
                layers.append(nn.Dropout(spec.dropout))
            layers.append(spec.activation())
            prev_dim = spec.out_dim

        # Final classifier layer
        self.final_linear = nn.Linear(prev_dim, config.num_classes)
        layers.append(self.final_linear)

        self.net = nn.Sequential(*layers)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x = x.view(x.size(0), -1)
        return self.net(x)

    def get_layer_params(self):
        param_groups = []
        for i, spec in enumerate(self.layers_specs):
            linear_layer = self.net[i * (4 if spec.batch_norm or spec.dropout > 0 else 3)]
            pass
        return self.layers_specs

# %% [markdown]
# Early Stopping (don't change)

# %%
class EarlyStopping:
    def __init__(self, patience: int = 10, min_delta: float = 1e-4):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.best_loss = float('inf')
        self.should_stop = False

    def __call__(self, val_loss: float) -> bool:
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.should_stop = True
        return self.should_stop

# %% [markdown]
# Trainer (don't change)

# %%
class Trainer:
    def __init__(self, model: nn.Module, config: TrainConfig):
        self.model = model.to(DEVICE)
        self.config = config
        self.criterion = nn.CrossEntropyLoss()
        self.optimizer = self._build_optimizer()
        self.scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
        self.early_stopping = EarlyStopping(patience=config.patience,
                                            min_delta=config.min_delta)

        self.history = {"train_loss": [], "train_acc": [],
                        "val_loss": [], "val_acc": []}

    def _build_optimizer(self):

        # Collect all Linear layers in the order they appear
        linear_layers = []
        for name, module in self.model.named_modules():
            if isinstance(module, nn.Linear):
                linear_layers.append((name, module))

        param_groups = []

        for i, spec in enumerate(self.model.layers_specs):
            name, layer = linear_layers[i]
            param_groups.append({
                'params': layer.parameters(),
                'weight_decay': spec.weight_decay
            })

        final_name, final_layer = linear_layers[-1]
        param_groups.append({
            'params': final_layer.parameters(),
            'weight_decay': 0.0
        })

        return torch.optim.SGD(param_groups, momentum=0.9, nesterov=True, lr=self.config.lr)

    def _train_epoch(self, loader: DataLoader):
        self.model.train()
        total_loss = 0.0
        correct = 0
        total = 0

        for data, target in loader:
            data, target = data.to(DEVICE), target.to(DEVICE)

            self.optimizer.zero_grad()
            with torch.cuda.amp.autocast(enabled=use_amp):
                output = self.model(data)
                loss = self.criterion(output, target)

            self.scaler.scale(loss).backward()
            self.scaler.step(self.optimizer)
            self.scaler.update()

            total_loss += loss.item() * data.size(0)
            correct += (output.argmax(1) == target).sum().item()
            total += data.size(0)

        return total_loss / total, correct / total

    @torch.no_grad()
    def _eval_epoch(self, loader: DataLoader):
        self.model.eval()
        total_loss = 0.0
        correct = 0
        total = 0

        for data, target in loader:
            data, target = data.to(DEVICE), target.to(DEVICE)
            with torch.cuda.amp.autocast(enabled=use_amp):
                output = self.model(data)
                loss = self.criterion(output, target)

            total_loss += loss.item() * data.size(0)
            correct += (output.argmax(1) == target).sum().item()
            total += data.size(0)

        return total_loss / total, correct / total

    def fit(self, train_loader: DataLoader, val_loader: DataLoader):
        print("🚀 Starting training...\n")
        for epoch in range(1, self.config.epochs + 1):
            train_loss, train_acc = self._train_epoch(train_loader)
            val_loss, val_acc     = self._eval_epoch(val_loader)

            self.history["train_loss"].append(train_loss)
            self.history["train_acc"].append(train_acc)
            self.history["val_loss"].append(val_loss)
            self.history["val_acc"].append(val_acc)

            print(f"Epoch {epoch:3d} | "
                  f"Train Loss: {train_loss:.4f} Acc: {train_acc:.4f} | "
                  f"Val Loss: {val_loss:.4f} Acc: {val_acc:.4f}")

            if self.early_stopping(val_loss):
                print(f"\n🛑 Early stopping triggered at epoch {epoch}")
                break

        print("\n✅ Training complete!")

    @torch.no_grad()
    def evaluate(self, loader: DataLoader):
        return self._eval_epoch(loader)

    @torch.no_grad()
    def predict_all(self, loader: DataLoader):
        self.model.eval()
        all_preds, all_targets = [], []
        for x, y in loader:
            x = x.to(DEVICE, non_blocking=True)
            logits = self.model(x)
            preds = logits.argmax(dim=1).cpu().numpy()
            all_preds.append(preds)
            all_targets.append(y.numpy())
        return np.concatenate(all_preds), np.concatenate(all_targets)


    def save(self, path: str = "mlp_best.pt"):
        torch.save(self.model.state_dict(), path)
        print(f"💾 Model saved to {path}")

# %% [markdown]
# Run (do change)

# %%
train_cfg = TrainConfig(
    batch_size=128,
    epochs=100,
    lr=1e-4,
    patience=5,
    val_fraction=0.1
)

data_mgr = DataManager(
    dataset_class=datasets.KMNIST,
    val_fraction=train_cfg.val_fraction,
    batch_size=train_cfg.batch_size,
    seed=train_cfg.seed
)
train_loader, val_loader, test_loader = data_mgr.get_loaders()

model_cfg = ModelConfig(
    layers=[
        LayerSpec(out_dim=512, dropout=0.2, batch_norm=True,  activation=nn.ReLU, weight_decay=1e-4),
        LayerSpec(out_dim=256, dropout=0.2, batch_norm=True,  activation=nn.ReLU, weight_decay=1e-4),
        LayerSpec(out_dim=128, dropout=0.1, batch_norm=True,  activation=nn.ReLU, weight_decay=1e-4),
    ]
)


# Build model
model = MLPFromConfig(model_cfg)
print(summary(model, input_size=(1, 28, 28)))

trainer = Trainer(model, train_cfg)
trainer.fit(train_loader, val_loader)
trainer.save("mlp_colab_best.pt")
# Out:
# 100%|██████████| 18.2M/18.2M [00:14<00:00, 1.21MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 188kB/s]
# 100%|██████████| 3.04M/3.04M [00:02<00:00, 1.02MB/s]
# 100%|██████████| 5.12k/5.12k [00:00<00:00, 13.9MB/s]
# Train: 54000 | Val: 6000 | Test: 10000
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLPFromConfig                            [1, 10]                   --
# ├─Sequential: 1-1                        [1, 10]                   --
# │    └─Linear: 2-1                       [1, 512]                  401,920
# │    └─BatchNorm1d: 2-2                  [1, 512]                  1,024
# │    └─Dropout: 2-3                      [1, 512]                  --
# │    └─ReLU: 2-4                         [1, 512]                  --
# │    └─Linear: 2-5                       [1, 256]                  131,328
# │    └─BatchNorm1d: 2-6                  [1, 256]                  512
# │    └─Dropout: 2-7                      [1, 256]                  --
# │    └─ReLU: 2-8                         [1, 256]                  --
# │    └─Linear: 2-9                       [1, 128]                  32,896
# │    └─BatchNorm1d: 2-10                 [1, 128]                  256
# │    └─Dropout: 2-11                     [1, 128]                  --
# │    └─ReLU: 2-12                        [1, 128]                  --
# │    └─Linear: 2-13                      [1, 10]                   1,290
# ==========================================================================================
# Total params: 569,226
# Trainable params: 569,226
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 0.57
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 2.28
# Estimated Total Size (MB): 2.29
# ==========================================================================================
# 🚀 Starting training...
# /tmp/ipython-input-2705984033.py:7: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   self.scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:668: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# /tmp/ipython-input-2705984033.py:49: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# /tmp/ipython-input-2705984033.py:72: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# Epoch   1 | Train Loss: 2.0675 Acc: 0.3104 | Val Loss: 1.7252 Acc: 0.6268
# Epoch   2 | Train Loss: 1.6058 Acc: 0.5899 | Val Loss: 1.3755 Acc: 0.7093
# Epoch   3 | Train Loss: 1.3297 Acc: 0.6758 | Val Loss: 1.1473 Acc: 0.7422
# Epoch   4 | Train Loss: 1.1465 Acc: 0.7165 | Val Loss: 1.0015 Acc: 0.7597
# Epoch   5 | Train Loss: 1.0208 Acc: 0.7416 | Val Loss: 0.8898 Acc: 0.7795
# Epoch   6 | Train Loss: 0.9263 Acc: 0.7614 | Val Loss: 0.8071 Acc: 0.7947
# Epoch   7 | Train Loss: 0.8498 Acc: 0.7785 | Val Loss: 0.7377 Acc: 0.8075
# Epoch   8 | Train Loss: 0.7931 Acc: 0.7903 | Val Loss: 0.6855 Acc: 0.8197
# Epoch   9 | Train Loss: 0.7399 Acc: 0.8038 | Val Loss: 0.6394 Acc: 0.8297
# Epoch  10 | Train Loss: 0.7014 Acc: 0.8121 | Val Loss: 0.6029 Acc: 0.8367
# Epoch  11 | Train Loss: 0.6647 Acc: 0.8198 | Val Loss: 0.5703 Acc: 0.8432
# Epoch  12 | Train Loss: 0.6337 Acc: 0.8278 | Val Loss: 0.5429 Acc: 0.8482
# Epoch  13 | Train Loss: 0.6074 Acc: 0.8329 | Val Loss: 0.5187 Acc: 0.8563
# Epoch  14 | Train Loss: 0.5826 Acc: 0.8393 | Val Loss: 0.5003 Acc: 0.8598
# Epoch  15 | Train Loss: 0.5601 Acc: 0.8452 | Val Loss: 0.4762 Acc: 0.8655
# Epoch  16 | Train Loss: 0.5434 Acc: 0.8487 | Val Loss: 0.4591 Acc: 0.8712
# Epoch  17 | Train Loss: 0.5257 Acc: 0.8523 | Val Loss: 0.4433 Acc: 0.8752
# Epoch  18 | Train Loss: 0.5089 Acc: 0.8570 | Val Loss: 0.4316 Acc: 0.8778
# Epoch  19 | Train Loss: 0.4941 Acc: 0.8606 | Val Loss: 0.4171 Acc: 0.8812
# Epoch  20 | Train Loss: 0.4809 Acc: 0.8649 | Val Loss: 0.4057 Acc: 0.8845
# Epoch  21 | Train Loss: 0.4677 Acc: 0.8670 | Val Loss: 0.3938 Acc: 0.8860
# Epoch  22 | Train Loss: 0.4567 Acc: 0.8699 | Val Loss: 0.3827 Acc: 0.8870
# Epoch  23 | Train Loss: 0.4455 Acc: 0.8733 | Val Loss: 0.3740 Acc: 0.8890
# Epoch  24 | Train Loss: 0.4369 Acc: 0.8760 | Val Loss: 0.3631 Acc: 0.8920
# Epoch  25 | Train Loss: 0.4262 Acc: 0.8785 | Val Loss: 0.3564 Acc: 0.8928
# Epoch  26 | Train Loss: 0.4162 Acc: 0.8804 | Val Loss: 0.3485 Acc: 0.8947
# Epoch  27 | Train Loss: 0.4088 Acc: 0.8817 | Val Loss: 0.3424 Acc: 0.8980
# Epoch  28 | Train Loss: 0.4001 Acc: 0.8852 | Val Loss: 0.3358 Acc: 0.8998
# Epoch  29 | Train Loss: 0.3912 Acc: 0.8882 | Val Loss: 0.3283 Acc: 0.9020
# Epoch  30 | Train Loss: 0.3860 Acc: 0.8890 | Val Loss: 0.3214 Acc: 0.9032
# Epoch  31 | Train Loss: 0.3780 Acc: 0.8907 | Val Loss: 0.3156 Acc: 0.9058
# Epoch  32 | Train Loss: 0.3693 Acc: 0.8922 | Val Loss: 0.3106 Acc: 0.9072
# Epoch  33 | Train Loss: 0.3639 Acc: 0.8948 | Val Loss: 0.3039 Acc: 0.9080
# Epoch  34 | Train Loss: 0.3574 Acc: 0.8967 | Val Loss: 0.2999 Acc: 0.9073
# Epoch  35 | Train Loss: 0.3522 Acc: 0.8984 | Val Loss: 0.2958 Acc: 0.9098
# Epoch  36 | Train Loss: 0.3462 Acc: 0.9001 | Val Loss: 0.2898 Acc: 0.9140
# Epoch  37 | Train Loss: 0.3430 Acc: 0.8997 | Val Loss: 0.2846 Acc: 0.9130
# Epoch  38 | Train Loss: 0.3381 Acc: 0.9019 | Val Loss: 0.2842 Acc: 0.9135
# Epoch  39 | Train Loss: 0.3312 Acc: 0.9035 | Val Loss: 0.2766 Acc: 0.9177
# Epoch  40 | Train Loss: 0.3245 Acc: 0.9048 | Val Loss: 0.2722 Acc: 0.9187
# Epoch  41 | Train Loss: 0.3205 Acc: 0.9073 | Val Loss: 0.2705 Acc: 0.9198
# Epoch  42 | Train Loss: 0.3163 Acc: 0.9076 | Val Loss: 0.2674 Acc: 0.9185
# Epoch  43 | Train Loss: 0.3122 Acc: 0.9097 | Val Loss: 0.2636 Acc: 0.9215
# Epoch  44 | Train Loss: 0.3119 Acc: 0.9091 | Val Loss: 0.2576 Acc: 0.9222
# Epoch  45 | Train Loss: 0.3057 Acc: 0.9109 | Val Loss: 0.2545 Acc: 0.9225
# Epoch  46 | Train Loss: 0.3039 Acc: 0.9114 | Val Loss: 0.2527 Acc: 0.9235
# Epoch  47 | Train Loss: 0.2991 Acc: 0.9129 | Val Loss: 0.2494 Acc: 0.9233
# Epoch  48 | Train Loss: 0.2929 Acc: 0.9141 | Val Loss: 0.2482 Acc: 0.9230
# Epoch  49 | Train Loss: 0.2883 Acc: 0.9161 | Val Loss: 0.2431 Acc: 0.9265
# Epoch  50 | Train Loss: 0.2900 Acc: 0.9154 | Val Loss: 0.2414 Acc: 0.9267
# Epoch  51 | Train Loss: 0.2842 Acc: 0.9173 | Val Loss: 0.2391 Acc: 0.9288
# Epoch  52 | Train Loss: 0.2800 Acc: 0.9173 | Val Loss: 0.2379 Acc: 0.9273
# Epoch  53 | Train Loss: 0.2759 Acc: 0.9182 | Val Loss: 0.2324 Acc: 0.9302
# Epoch  54 | Train Loss: 0.2722 Acc: 0.9210 | Val Loss: 0.2318 Acc: 0.9293
# Epoch  55 | Train Loss: 0.2676 Acc: 0.9217 | Val Loss: 0.2278 Acc: 0.9320
# Epoch  56 | Train Loss: 0.2674 Acc: 0.9219 | Val Loss: 0.2244 Acc: 0.9325
# Epoch  57 | Train Loss: 0.2645 Acc: 0.9225 | Val Loss: 0.2240 Acc: 0.9333
# Epoch  58 | Train Loss: 0.2590 Acc: 0.9243 | Val Loss: 0.2202 Acc: 0.9345
# Epoch  59 | Train Loss: 0.2571 Acc: 0.9244 | Val Loss: 0.2196 Acc: 0.9363
# Epoch  60 | Train Loss: 0.2582 Acc: 0.9238 | Val Loss: 0.2179 Acc: 0.9355
# Epoch  61 | Train Loss: 0.2529 Acc: 0.9266 | Val Loss: 0.2156 Acc: 0.9363
# Epoch  62 | Train Loss: 0.2504 Acc: 0.9275 | Val Loss: 0.2129 Acc: 0.9372
# Epoch  63 | Train Loss: 0.2465 Acc: 0.9277 | Val Loss: 0.2126 Acc: 0.9375
# Epoch  64 | Train Loss: 0.2464 Acc: 0.9278 | Val Loss: 0.2099 Acc: 0.9383
# Epoch  65 | Train Loss: 0.2406 Acc: 0.9290 | Val Loss: 0.2082 Acc: 0.9380
# Epoch  66 | Train Loss: 0.2414 Acc: 0.9285 | Val Loss: 0.2070 Acc: 0.9383
# Epoch  67 | Train Loss: 0.2367 Acc: 0.9314 | Val Loss: 0.2037 Acc: 0.9403
# Epoch  68 | Train Loss: 0.2340 Acc: 0.9313 | Val Loss: 0.2023 Acc: 0.9413
# Epoch  69 | Train Loss: 0.2318 Acc: 0.9325 | Val Loss: 0.2006 Acc: 0.9402
# Epoch  70 | Train Loss: 0.2283 Acc: 0.9328 | Val Loss: 0.1988 Acc: 0.9415
# Epoch  71 | Train Loss: 0.2284 Acc: 0.9326 | Val Loss: 0.1989 Acc: 0.9410
# Epoch  72 | Train Loss: 0.2261 Acc: 0.9341 | Val Loss: 0.1973 Acc: 0.9413
# Epoch  73 | Train Loss: 0.2220 Acc: 0.9344 | Val Loss: 0.1960 Acc: 0.9430
# Epoch  74 | Train Loss: 0.2221 Acc: 0.9338 | Val Loss: 0.1949 Acc: 0.9435
# Epoch  75 | Train Loss: 0.2210 Acc: 0.9346 | Val Loss: 0.1935 Acc: 0.9433
# Epoch  76 | Train Loss: 0.2184 Acc: 0.9365 | Val Loss: 0.1917 Acc: 0.9427
# Epoch  77 | Train Loss: 0.2139 Acc: 0.9372 | Val Loss: 0.1906 Acc: 0.9443
# Epoch  78 | Train Loss: 0.2136 Acc: 0.9373 | Val Loss: 0.1879 Acc: 0.9447
# Epoch  79 | Train Loss: 0.2137 Acc: 0.9364 | Val Loss: 0.1871 Acc: 0.9453
# Epoch  80 | Train Loss: 0.2082 Acc: 0.9394 | Val Loss: 0.1864 Acc: 0.9457
# Epoch  81 | Train Loss: 0.2093 Acc: 0.9389 | Val Loss: 0.1852 Acc: 0.9452
# Epoch  82 | Train Loss: 0.2089 Acc: 0.9378 | Val Loss: 0.1839 Acc: 0.9470
# Epoch  83 | Train Loss: 0.2041 Acc: 0.9396 | Val Loss: 0.1830 Acc: 0.9462
# Epoch  84 | Train Loss: 0.2022 Acc: 0.9405 | Val Loss: 0.1814 Acc: 0.9472
# Epoch  85 | Train Loss: 0.2045 Acc: 0.9392 | Val Loss: 0.1809 Acc: 0.9455
# Epoch  86 | Train Loss: 0.2013 Acc: 0.9397 | Val Loss: 0.1813 Acc: 0.9472
# Epoch  87 | Train Loss: 0.1999 Acc: 0.9414 | Val Loss: 0.1780 Acc: 0.9490
# Epoch  88 | Train Loss: 0.1968 Acc: 0.9420 | Val Loss: 0.1772 Acc: 0.9482
# Epoch  89 | Train Loss: 0.1948 Acc: 0.9419 | Val Loss: 0.1760 Acc: 0.9473
# Epoch  90 | Train Loss: 0.1932 Acc: 0.9431 | Val Loss: 0.1751 Acc: 0.9478
# Epoch  91 | Train Loss: 0.1908 Acc: 0.9436 | Val Loss: 0.1739 Acc: 0.9487
# Epoch  92 | Train Loss: 0.1907 Acc: 0.9441 | Val Loss: 0.1743 Acc: 0.9485
# Epoch  93 | Train Loss: 0.1887 Acc: 0.9438 | Val Loss: 0.1738 Acc: 0.9492
# Epoch  94 | Train Loss: 0.1854 Acc: 0.9456 | Val Loss: 0.1719 Acc: 0.9488
# Epoch  95 | Train Loss: 0.1854 Acc: 0.9445 | Val Loss: 0.1698 Acc: 0.9500
# Epoch  96 | Train Loss: 0.1849 Acc: 0.9450 | Val Loss: 0.1704 Acc: 0.9498
# Epoch  97 | Train Loss: 0.1850 Acc: 0.9446 | Val Loss: 0.1691 Acc: 0.9505
# Epoch  98 | Train Loss: 0.1829 Acc: 0.9450 | Val Loss: 0.1676 Acc: 0.9497
# Epoch  99 | Train Loss: 0.1798 Acc: 0.9459 | Val Loss: 0.1673 Acc: 0.9497
# Epoch 100 | Train Loss: 0.1788 Acc: 0.9464 | Val Loss: 0.1664 Acc: 0.9505
#
# ✅ Training complete!
# 💾 Model saved to mlp_colab_best.pt

# %% [markdown]
# Visuazize the train

# %%
history = trainer.history

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"],   label="Val Loss")
plt.title("Loss")
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history["train_acc"], label="Train Acc")
plt.plot(history["val_acc"],   label="Val Acc")
plt.title("Accuracy")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# Visualized the test (do change)

# %%
# entire test result
test_loss, test_acc = trainer.evaluate(test_loader)
print(f"🏆 Test Loss: {test_loss:.4f} | Test Accuracy: {test_acc:.4f}")

# predictions
preds, targets = trainer.predict_all(test_loader)

# confusion matrix
cm = confusion_matrix(targets, preds)
plt.figure()
plt.imshow(cm)
plt.title("Confusion Matrix (Test)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.colorbar()
plt.show()


# per-class report
print("Classification report (Test):")
print(classification_report(targets, preds, digits=4))
# Out:
# /tmp/ipython-input-2705984033.py:72: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp):
# 🏆 Test Loss: 0.3877 | Test Accuracy: 0.8791
# Classification report (Test):
#               precision    recall  f1-score   support
#
#            0     0.9187    0.8930    0.9057      1000
#            1     0.8746    0.8580    0.8662      1000
#            2     0.8105    0.8470    0.8284      1000
#            3     0.8774    0.9450    0.9100      1000
#            4     0.8674    0.8570    0.8622      1000
#            5     0.9460    0.8410    0.8904      1000
#            6     0.8389    0.9370    0.8852      1000
#            7     0.9311    0.8520    0.8898      1000
#            8     0.8386    0.8940    0.8654      1000
#            9     0.9126    0.8670    0.8892      1000
#
#     accuracy                         0.8791     10000
#    macro avg     0.8816    0.8791    0.8793     10000
# weighted avg     0.8816    0.8791    0.8793     10000
